# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/macintoshhd/Data Science projects/Weather'

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'code_snippets',
#  'Untitled.ipynb',
#  'DataScience_final_project_weather.pdf',
#  'Weather_data',
#  '.ipynb_checkpoints']

# %%
os.chdir("Weather_data")

# %%
os.listdir()
# Out:
# ['weather_data_train.csv',
#  'weather_data_train_labels.csv',
#  'weather_data_test_labels.csv',
#  'weather_data_test.csv']

# %%
reviews = pd.read_csv('weather_data_train.csv', delimiter=,')
reviews
# Out:
#                                                                                                                                                                                                                                                                                                                        datetime;T_mu;Po_mu;P_mu;Ff_mu;Tn_mu;Tx_mu;VV_mu;Td_mu;T_var;Po_var;P_var;Ff_var;Tn_var;Tx_var;VV_var;Td_var
# 2006-09-20;14 487500000000002;751  3;751             6375;3          5;13                3;15               95;11              425;12             549999999999999;0  9269642857142856;1  0085714285714753;0  9798214285714614;1  1428571428571428;0   31999999999999984;4   204999999999996;155    59071428571428;1                                     9942857142857189
# ...
